# %%
import simplegoodturing as sgt
from simplegoodturing import Estimator
import pylab
pylab.rcParams['figure.figsize'] = (8, 6)
pylab.rcParams['axes.xmargin'] = .3
pylab.rcParams['axes.ymargin'] = .3
from pylab import *

# %%
N = sgt.sgt.ChinesePluralsTest.input
N_x, N_y = zip(*N.items())

# %%
loglog(N_x, N_y, 'o')

# %%
show()

# %%
estimator = Estimator(N=N)

# %%
Z = estimator.Z
Z_x, Z_y = zip(*Z.items())

# %%
loglog(Z_x, Z_y, 'o', [1, 8000], [exp(estimator.a), exp(log(8000) * estimator.b + estimator.a)])

# %%
loglog(N_x, [estimator.turing_rstar_unnorm(r)/r
             if estimator.turing_rstar_unnorm(r)
             else None
             for r in N_x], 'o',
       range(1, 8000), [estimator.linear_rstar_unnorm(r)/r for r in range(1, 8000)])

# %%
loglog(N_x, [estimator.rstar(r)/r for r in N_x], 'o')
