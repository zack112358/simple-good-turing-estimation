# %%
import thispackage as sgt
from thispackage.sgt import Estimator
pylab.rcParams['figure.figsize'] = (10.0, 8.0)

# %%
N = sgt.sgt.ProsodyTest.input
N_x, N_y = zip(*N.items())

# %%
loglog(N_x, N_y, '+')

# %%
estimator = Estimator(N=N, max_r=8000)

# %%
Z = estimator.Z
Z_x, Z_y = zip(*Z.items())

# %%
loglog(Z_x, Z_y, '+', [1, 8000], [exp(estimator.a), exp(log(8000) * estimator.b + estimator.a)])
# Out:
# [<matplotlib.lines.Line2D at 0x112d86950>,
#  <matplotlib.lines.Line2D at 0x11323bb50>]

# %%
loglog(N_x, [estimator.turing_estimate(x)/x if estimator.turing_estimate(x) else None for x in N_x], '+',
       range(1, 8000), [estimator.linear_estimate(x)/x for x in range(1, 8000)])
# Out:
# [<matplotlib.lines.Line2D at 0x113437490>,
#  <matplotlib.lines.Line2D at 0x11395fb10>]

# %%
loglog(N_x, [estimator.estimate(r)/r for r in N_x], '+')
